# %% [markdown]
# # Q1: Define overfitting and underfitting in machine learning. What are the consequences of each, and how can they be mitigated?

# %% [markdown]
# # Underfitting:
# #     A statistical model or a machine learning algorithm is said to have underfitting when it cannot capture the underlying trend of the data,
# #     i.e., it only performs well on training data but performs poorly on testing data.
#
# # Reasons for Underfitting:
#
# # 1.High bias and low variance
# # 2.The size of the training dataset used is not enough.
# # 3.The model is too simple.
# # 4.Training data is not cleaned and also contains noise in it.
#
# # Techniques to reduce underfitting:
#
# # 1.Increase model complexity
# # 2.Increase the number of features, performing feature engineering
# # 3.Remove noise from the data.
# # 4.Increase the number of epochs or increase the duration of training to get better results.
#
# # OverFitting:
# #     Overfitting means that your model makes not accurate predictions.
# #     In this case, train error is very small and val/test error is large.
#
#
# # Reasons for Overfitting are as follows:
# # 1.High variance and low bias
# # 2,The model is too complex
# # 3.The size of the training data
#
# # Techniques to reduce overfitting:
#
# # 1.Increase training data.
# # 2.Reduce model complexity.
# # 3.Early stopping during the training phase (have an eye over the loss over the training period as soon as loss begins to increase stop training).
# # 4.Ridge Regularization and Lasso Regularization
# # 5.Use dropout for neural networks to tackle overfitting.
# #
#
#
# #

# %% [markdown]
# # Q2: How can we reduce overfitting? Explain in brief.

# %% [markdown]
# # Techniques to reduce overfitting:
#
# # 1.Increase training data.
# # 2.Reduce model complexity.
# # 3.Early stopping during the training phase (have an eye over the loss over the training period as soon as loss begins to increase stop training).
# # 4.Ridge Regularization and Lasso Regularization
# # 5.Use dropout for neural networks to tackle overfitting.
#
# #

# %% [markdown]
# # Q3: Explain underfitting. List scenarios where underfitting can occur in ML.

# %% [markdown]
# # Underfitting:
# #     A statistical model or a machine learning algorithm is said to have underfitting when it cannot capture the underlying trend of the data,
# #     i.e., it only performs well on training data but performs poorly on testing data.
# # Reasons for Underfitting:
# # 1.High bias and low variance
# # 2.The size of the training dataset used is not enough.
# # 3.The model is too simple.
# # 4.Training data is not cleaned and also contains noise in it.
#
# #
# #

# %% [markdown]
# # Q4: Explain the bias-variance tradeoff in machine learning. What is the relationship between bias and variance, and how do they affect model performance?

# %% [markdown]
# # What is bias?
#
# # Bias is the difference between the average prediction of our model and the correct value which we are trying to predict.
# # #
# # What is variance?
#
# # Variance is the variability of model prediction for a given data point or a value which tells us spread of our data.
# # Model with high variance pays a lot of attention to training data and does not generalize on the data which it hasn’t seen before.
# # As a result, such models perform very well on training data but has high error rates on test data.
# # #
# # Why is Bias Variance Tradeoff?
#
# # If our model is too simple and has very few parameters then it may have high bias and low variance.
# # On the other hand if our model has large number of parameters then it’s going to have high variance and low bias.
# # So we need to find the right/good balance without overfitting and underfitting the data.
#
# # This tradeoff in complexity is why there is a tradeoff between bias and variance. An algorithm can’t be more complex and less complex at the same time.
#
# #
# #

# %% [markdown]
# # Q5: Discuss some common methods for detecting overfitting and underfitting in machine learning models. How can you determine whether your model is overfitting or underfitting?

# %% [markdown]
# # overfiting detection:
# # Since overfitting is a common problem, it is essential to detect it.
# # To detect overfitted data, the prerequisite is that it must be used on test data.
# # The first step in this regard is to divide the dataset into two separate training and testing sets. If the model performed exponentially better on the training set than the test set, it is clearly overfitted.
# # #
#
# # Underfiting detection:
# #     where your model does not fit the training data well enough. In that case both training loss and validation loss are similar, but poor.
#
# #
# #

# %% [markdown]
# # Q6: Compare and contrast bias and variance in machine learning. What are some examples of high bias and high variance models, and how do they differ in terms of their performance?

# %% [markdown]
# ![image.png](attachment:12692ec4-6db3-4fda-819f-9fde70ab7814.png)
#
# #
# #

# %% [markdown]
# # Q7: What is regularization in machine learning, and how can it be used to prevent overfitting? Describe some common regularization techniques and how they work.

# %% [markdown]
# # Regularization in Machine Learning
# # Regularization is a technique used to reduce errors by fitting the function appropriately on the given training set and avoiding overfitting or underfiting. The commonly used regularization techniques are :
#
# # 1.Lasso Regularization – L1 Regularization
# # 2.Ridge Regularization – L2 Regularization
# # 3.Elastic Net Regularization – L1 and L2 Regularization
